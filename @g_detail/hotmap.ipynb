# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %%
root = 'PUMP-TcnED-dis.csv'
df = pd.read_csv(root, index_col=0)
df = df.rename(columns={'0': 'label'})

# %%
df = df.apply(lambda x: (x - np.min(x)) / (np.max(x) - np.min(x)))

# %%
true = df[df.label == 0]
false = df[df.label == 1]

# %%
label = df['label'].values
true = true.iloc[:, 1:]
false = false.iloc[:, 1:]

# %%
len(false)
# Out:
# 203

# %%
pindex=[48,85,86,87,88,89,153,154,165]  # 
pindex = [str(i) for i in pindex]

# %%
tindex=[0,2,6,16,24,34,46,105,198,199,]
true_df = true.iloc[:50, 100:200]
# true_df = true[pindex].values[tindex]
# true_df = true[pindex].values[100:200]
sns.heatmap(data=true_df,#矩阵数据集，数据的index和columns分别为heatmap的y轴方向和x轴方向标签
                 vmin=0,#图例（右侧颜色条color bar）中最小显示值 
                 vmax=1,#图例（右侧颜色条color bar）中最大显示值
           )
plt.show()

# %%
findex=[0,1,3,6,11,18,31,33,37,45,46,50,57,68,69,74,75,86,87,89,90]
false_df = false.iloc[:50, 100:200]
# false_df = false[pindex].values[findex]
# false_df = false[pindex].values[50:96]
sns.heatmap(data=false_df,#矩阵数据集，数据的index和columns分别为heatmap的y轴方向和x轴方向标签
                 vmin=0,#图例（右侧颜色条color bar）中最小显示值 
                 vmax=1,#图例（右侧颜色条color bar）中最大显示值
           )
plt.show()
